# %% [markdown]
# #MS COCO

# %%
import tensorflow_datasets as tfds

ds, ds_info = tfds.load('coco', split='train', with_info=True, data_dir='./')
fig = tfds.show_examples(ds, ds_info)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-c64141831e09> in <module>
#       1 import tensorflow_datasets as tfds
#       2
# ----> 3 ds, ds_info = tfds.load('coco', split='train', with_info=True, data_dir='./')
#       4 fig = tfds.show_examples(ds, ds_info)
#
# /usr/local/lib/python3.8/site-packages/tensorflow_datasets/core/load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     331   if download:
#     332     download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 333     dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#     334
#     335   if as_dataset_kwargs is None:
#
# /usr/local/lib/python3.8/site-packages/tensorflow_datasets/core/dataset_builder.py in download_and_prepare(self, download_dir, download_config)
#     402         self.info.dataset_size + self.info.download_size,
#     403         directory=self._data_dir_root):
# --> 404       raise IOError(
#     405           "Not enough disk space. Needed: {} (download: {}, generated: {})"
#     406           .format(
#
# OSError: Not enough disk space. Needed: 37.57 GiB (download: 37.57 GiB, generated: Unknown size)
