# %% [markdown]
# ## load MNIST data

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop, Adam

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
import matplotlib.pyplot as plt
plt.imshow(x_train[0])
predict_data = x_train[0]
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
num_classes = 10

# %%
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ## Create Model

# %%
model = Sequential()

# %%
model.add(Dense(512, activation='relu', input_shape=(784,))) # input layer
model.add(Dense(512, activation='relu')) # hidden layer1
model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model.compile(loss='categorical_crossentropy', optimizer=RMSprop(lr=0.001), metrics=['accuracy'])
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(lr=0.00001), metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model fit

# %%
batch_size = 128
epochs = 10
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 4s 68us/step - loss: 1.7415 - accuracy: 0.6119 - val_loss: 1.1639 - val_accuracy: 0.8140
# Epoch 2/10
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.8345 - accuracy: 0.8385 - val_loss: 0.5720 - val_accuracy: 0.8746
# Epoch 3/10
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.4959 - accuracy: 0.8798 - val_loss: 0.4061 - val_accuracy: 0.9002
# Epoch 4/10
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.3876 - accuracy: 0.8984 - val_loss: 0.3405 - val_accuracy: 0.9117
# Epoch 5/10
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.3367 - accuracy: 0.9088 - val_loss: 0.3055 - val_accuracy: 0.9188
# Epoch 6/10
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.3056 - accuracy: 0.9157 - val_loss: 0.2830 - val_accuracy: 0.9248
# Epoch 7/10
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.2833 - accuracy: 0.9210 - val_loss: 0.2643 - val_accuracy: 0.9276
# Epoch 8/10
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.2663 - accuracy: 0.9258 - val_loss: 0.2515 - val_accuracy: 0.9305
# Epoch 9/10
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.2520 - accuracy: 0.9293 - val_loss: 0.2388 - val_accuracy: 0.9336
# Epoch 10/10
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.2399 - accuracy: 0.9328 - val_loss: 0.2291 - val_accuracy: 0.9359
