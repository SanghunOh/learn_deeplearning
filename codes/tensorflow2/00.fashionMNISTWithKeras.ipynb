# %% [markdown]
# #fashion MNIST with Keras
# https://www.tensorflow.org/tutorials/keras/classification

# %%
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0

# plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images, train_labels[0]
# Out:
# 9

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
hist = model.fit(train_images, train_labels, epochs=10, batch_size=256)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 235/235 [==============================] - 1s 5ms/step - loss: 1.7720 - accuracy: 0.7113
# Epoch 2/10
# 235/235 [==============================] - 1s 5ms/step - loss: 1.6849 - accuracy: 0.7842
# Epoch 3/10
# 235/235 [==============================] - 1s 5ms/step - loss: 1.6709 - accuracy: 0.7969
# Epoch 4/10
# 235/235 [==============================] - 1s 5ms/step - loss: 1.6636 - accuracy: 0.8026
# Epoch 5/10
# 235/235 [==============================] - 1s 4ms/step - loss: 1.6583 - accuracy: 0.8071
# Epoch 6/10
# 235/235 [==============================] - 1s 5ms/step - loss: 1.6545 - accuracy: 0.8102
# Epoch 7/10
# 235/235 [==============================] - 1s 4ms/step - loss: 1.6520 - accuracy: 0.8121
# Epoch 8/10
# 235/235 [==============================] - 1s 5ms/step - loss: 1.6483 - accuracy: 0.8159
# Epoch 9/10
# 235/235 [==============================] - 1s 5ms/step - loss: 1.6464 - accuracy: 0.8174
# Epoch 10/10
# 235/235 [==============================] - 1s 4ms/step - loss: 1.6439 - accuracy: 0.8195

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 0s - loss: 1.6582 - accuracy: 0.8036

# %%
# probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])
predictions = model.predict(test_images)
predictions[0], np.argmax(predictions[0]), test_labels[0]
# Out:
# (array([3.0131915e-07, 4.9435966e-11, 5.1681677e-09, 7.8947764e-09,
#         6.2654903e-10, 1.4203134e-02, 2.3099692e-06, 1.8727151e-01,
#         1.0444069e-04, 7.9841834e-01], dtype=float32), 9, 9)
